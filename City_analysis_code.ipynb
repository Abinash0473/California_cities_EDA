# %%
#importing required applocations such as numpy,pandas,matplotlib,seaborn for data analysis

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
# loading the data set

# %%
df = pd.read_csv(r'C:\Users\KIIT\Documents\temp data\california_cities.csv', encoding= 'unicode_escape')

# %%
# BASIC INFORMATION OF THE DATA

# %%
df.shape
# Out:
# (482, 14)

# %%
df.head()
# Out:
#    Unnamed: 0         city       latd       longd  elevation_m  elevation_ft  \
# 0           0     Adelanto  34.576111 -117.432778        875.0        2871.0
# 1           1  AgouraHills  34.153333 -118.761667        281.0         922.0
# 2           2      Alameda  37.756111 -122.274444          NaN          33.0
# 3           3       Albany  37.886944 -122.297778          NaN          43.0
# 4           4     Alhambra  34.081944 -118.135000        150.0         492.0
#
#    population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0             31765            56.027           56.009             0.018
# 1             20330             7.822            7.793             0.029
# 2             75467            22.960           10.611            12.349
# 3             18969             5.465            1.788             3.677
# 4             83089             7.632            7.631             0.001
#
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0            city       latd       longd  elevation_m  \
# 0           0        Adelanto  34.576111 -117.432778        875.0
# 1           1     AgouraHills  34.153333 -118.761667        281.0
# 2           2         Alameda  37.756111 -122.274444          NaN
# 3           3          Albany  37.886944 -122.297778          NaN
# 4           4        Alhambra  34.081944 -118.135000        150.0
# 5           5      AlisoViejo  33.575000 -117.725556        127.0
# 6           6         Alturas  41.487222 -120.542500       1332.0
# 7           7      AmadorCity  38.419444 -120.824167        280.0
# 8           8  AmericanCanyon  38.168056 -122.252500         14.0
# 9           9         Anaheim  33.836111 -117.889722         48.0
#
#    elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0        2871.0             31765            56.027           56.009
# 1         922.0             20330             7.822            7.793
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0            482
# city                  482
# latd                  474
# longd                 473
# elevation_m           241
# elevation_ft          271
# population_total      481
# area_total_sq_mi      468
# area_land_sq_mi       479
# area_water_sq_mi      233
# area_total_km2        472
# area_land_km2         476
# area_water_km2        277
# area_water_percent    220
# dtype: int64

# %%
# CHECKING FOR UNIQUE VALUES

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          482 non-null    int64
#  1   city                482 non-null    object
#  2   latd                482 non-null    float64
#  3   longd               482 non-null    float64
#  4   elevation_m         434 non-null    float64
#  5   elevation_ft        470 non-null    float64
#  6   population_total    482 non-null    int64
#  7   area_total_sq_mi    480 non-null    float64
#  8   area_land_sq_mi     482 non-null    float64
#  9   area_water_sq_mi    481 non-null    float64
#  10  area_total_km2      477 non-null    float64
#  11  area_land_km2       478 non-null    float64
#  12  area_water_km2      478 non-null    float64
#  13  area_water_percent  477 non-null    float64
# dtypes: float64(11), int64(2), object(1)
# memory usage: 52.8+ KB

# %%
#CKECKING FOR NULL VALUES

# %%
pd.isnull(df)
# Out:
#      Unnamed: 0   city   latd  longd  elevation_m  elevation_ft  \
# 0         False  False  False  False        False         False
# 1         False  False  False  False        False         False
# 2         False  False  False  False         True         False
# 3         False  False  False  False         True         False
# 4         False  False  False  False        False         False
# ..          ...    ...    ...    ...          ...           ...
# 477       False  False  False  False        False         False
# 478       False  False  False  False        False         False
# 479       False  False  False  False        False         False
# 480       False  False  False  False        False         False
# 481       False  False  False  False        False         False
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0               False             False            False             False
# ...

# %%
pd.isnull(df).sum()
# Out:
# Unnamed: 0             0
# city                   0
# latd                   0
# longd                  0
# elevation_m           48
# elevation_ft          12
# population_total       0
# area_total_sq_mi       2
# area_land_sq_mi        0
# area_water_sq_mi       1
# area_total_km2         5
# area_land_km2          4
# area_water_km2         4
# area_water_percent     5
# dtype: int64

# %%
df.shape
# Out:
# (482, 14)

# %%
# DELEATING OF NULL VALUES FROM THE DATASET

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (427, 14)

# %%
pd.isnull(df).sum()
# Out:
# Unnamed: 0            0
# city                  0
# latd                  0
# longd                 0
# elevation_m           0
# elevation_ft          0
# population_total      0
# area_total_sq_mi      0
# area_land_sq_mi       0
# area_water_sq_mi      0
# area_total_km2        0
# area_land_km2         0
# area_water_km2        0
# area_water_percent    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'city', 'latd', 'longd', 'elevation_m', 'elevation_ft',
#        'population_total', 'area_total_sq_mi', 'area_land_sq_mi',
#        'area_water_sq_mi', 'area_total_km2', 'area_land_km2', 'area_water_km2',
#        'area_water_percent'],
#       dtype='object')

# %%
# CHECKING AND ANALYSIS OF DATA TYPES OF EACH COLUMN ELEMENTS

# %%
df['city'].dtypes
# Out:
# dtype('O')

# %%
df['latd'].dtypes
# Out:
# dtype('float64')

# %%
df['longd'].dtypes
# Out:
# dtype('float64')

# %%
df['elevation_m'].dtypes
# Out:
# dtype('float64')

# %%
df['elevation_ft'].dtypes
# Out:
# dtype('float64')

# %%
df['population_total'].dtypes
# Out:
# dtype('int64')

# %%
df['area_total_sq_mi'].dtypes
# Out:
# dtype('float64')

# %%
df['area_land_sq_mi'].dtypes
# Out:
# dtype('float64')

# %%
df['area_water_sq_mi'].dtypes
# Out:
# dtype('float64')

# %%
df['area_total_km2'].dtypes
# Out:
# dtype('float64')

# %%
df['area_land_km2'].dtypes
# Out:
# dtype('float64')

# %%
df['area_water_km2'].dtypes
# Out:
# dtype('float64')

# %%
df['area_water_percent'].dtypes
# Out:
# dtype('float64')

# %%
# ANALYSIS OF THE DATA

# %%
df.describe()
# Out:
#        Unnamed: 0        latd       longd  elevation_m  elevation_ft  \
# count  427.000000  427.000000  427.000000   427.000000    427.000000
# mean   242.018735   36.022693 -119.743048   182.416511    594.534660
# std    140.356018    2.298407    2.094783   311.501270   1024.317641
# min      0.000000   32.578333 -124.263333   -34.000000   -112.000000
# 25%    119.500000   33.964028 -121.835278    22.000000     71.500000
# 50%    242.000000   35.622500 -119.456389    67.000000    218.000000
# 75%    362.500000   37.884306 -117.964167   179.500000    562.500000
# max    481.000000   41.965000 -114.596389  2402.000000   7880.000000
#
#        population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# count      4.270000e+02        427.000000       427.000000        427.000000
# mean       6.045112e+04         17.374609        16.288689          1.092749
# std        2.040823e+05         35.018075        32.628631          4.251690
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'city', 'latd', 'longd', 'elevation_m', 'elevation_ft',
#        'population_total', 'area_total_sq_mi', 'area_land_sq_mi',
#        'area_water_sq_mi', 'area_total_km2', 'area_land_km2', 'area_water_km2',
#        'area_water_percent'],
#       dtype='object')

# %%
ax = sns.countplot(x = 'elevation_m',data = df)

# %%
ax = sns.countplot(x = 'elevation_m',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
ax = sns.countplot(data = df, x = 'elevation_m')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
from matplotlib import colors

# %%
sns.pairplot(df)

# %%
sns.relplot(x='latd',y='latd',hue='city',data=df)

# %%
sns.displot(df['latd'])

# %%
sns.displot(df['longd'])
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['elevation_m'])
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['area_total_sq_mi'])
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['area_land_sq_mi'])
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['area_water_sq_mi'])
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['area_total_km2'])
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['area_land_km2'])
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['area_water_km2'])
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(df['area_water_percent'])
# Out:
# C:\Users\KIIT\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x='latd',kind='box',data=df)

# %%
myf=df['latd'].value_counts()
myf
# Out:
# latd
# 34.100000    3
# 33.684167    2
# 34.102778    2
# 34.138333    2
# 32.678056    2
#             ..
# 34.130833    1
# 34.170833    1
# 37.011944    1
# 33.778889    1
# 34.133333    1
# Name: count, Length: 474, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
myf.plot(kind='pie')
plt.show()

# %%
myf.plot(kind='bar')
plt.show()

# %% [markdown]
# FOLLOWING ARE THE CONCLUSION POINTS OF EACH DATA:-
#   1.LATD:-
#     .Total 427 data values.
#     .Mean value of the latitude is 36.022693
#     .Maximum latd is of Tulelake.
#     .Minimum latd is of ImperialBeach.
#  2.LONGD:-
#    .Total 427 data values.
#     .Mean value of the longitude is -119.743048
#     .Maximum latd is of Blythe
#     .Minimum latd is of Fortuna
#  3.ELEVATION:-
#    .Total 427 data values.
#     .Mean value of the elevation is 182.416511
#     .Maximum latd is of MammothLakes
#     .Minimum latd is of Brawley
#  4.TOTAL POPULATION:-
#    .Total 427 data values.
#     .Mean value of the population is 6.045112e+04
#     .Maximum latd is of LosAngeles
#     .Minimum latd is of Pomona
#  5.TOTAL AREA:-
#    .Total 427 data values.
#     .Mean value of the total area is 17.374609
#     .Maximum latd is of LosAngeles
#     .Minimum latd is of AmadorCity
#  6.LAND AREA:-
#    .Total 427 data values.
#     .Mean value of the land area  is 16.288689
#     .Maximum latd is of LosAngeles
#     .Minimum latd is of AmadorCity
#  7.WATER AREA:-
#    .Total 427 data values.
#     .Mean value of the water area is 1.092749
#     .Maximum latd is of Los Angeles and San Diego
#     .Minimum latd is of San Bernardino
